# %% [markdown]
# ### Домашнее задание "Производная функции нескольких аргументов".

# %%
import numpy as np
from scipy.optimize import approx_fprime

# %% [markdown]
# Уровень 0:
#
# Посчитайте частные производные функций:
#
# 1) $f(x,y)=2x^2y^3 + 1/x + y^2x + 7$, а для этой функции также градиент в точке $(1,2)$
#
# 2) $f(x,y)=x^2y - sin(xy) + cos(x^2) + 6y$

# %%
# Посчитайте частные производные функций: 1)  𝑓(𝑥,𝑦)=2𝑥2𝑦3+1/𝑥+𝑦2𝑥+7 , а для этой функции также градиент в точке  (1,2)
def f1(v,c0,c1,c2,c3):
    return (c0 * v[0]**2*v[1]**3) + c1 * 1/v[0] + (c2 * v[1]**2*v[0]) + c3

# c0 = 2
# c1 = 1
# c2 = 1
# c3 = 7

# %%
from sympy import *
x, y = symbols('x y')

print(f'Частная производная по х: {diff((2*x**2*y**3) + 1/x + (y**2*x) + 7, x)}') #Частная производная по х
print(f'Частная производная по y: {diff((2*x**2*y**3) + 1/x + (y**2*x) + 7, y)}') #Частная производная по y
# Out:
# Частная производная по х: 4*x*y**3 + y**2 - 1/x**2
# Частная производная по y: 6*x**2*y**2 + 2*x*y

# %% [markdown]
# #### Проверим расчет частных производных руками:
# f'x = (2*x**2*y**3)'x + (1/x)'x + (y**2*x)'x +7'x = 4*x*y**3 - 1/x**2 + y**2 + 0 =  4*x*y**3 - 1/x**2 + y**2  - совпало
#
# f'y = (2*x**2*y**3)'y + (1/x)'y + (y**2*x)'y +7'y = 6*x**2*y**2 + 0 + 2*x*y + 0 = 6*x**2*y**2 + 2*x*y - совпало

# %%
#вычислим градиент в точке (1;2)
a = np.array([1., 2.])
from scipy.optimize import approx_fprime #импортируем ф-ю для расчета градиента

# %%
c0, c1, c2, c3 = (2, 1, 1, 7)
eps = np.sqrt(np.finfo(float).eps)
approx_fprime(a, f1, [eps, eps], c0, c1, c2, c3)
#первая координата – точка в которой вычисляем градиент, 
#вторая – наша фунция,
#третья – это погрешность вычисления, и коэффициенты из функции.
# Out:
# array([35.00000024, 28.00000024])

# %%
#Проверим расчет градиента руками:
x = 1
y = 2
fx = (4*x*y**3 + y**2 - 1/x**2) #находим значение частной производной по x в т. (2,1)
fy = (6*x**2*y**2 + 2*x*y) #находим значение частной производной по y в т. (2,1)

grad = np.array([fx,fy])
grad
# Out:
# array([35., 28.])

# %% [markdown]
# Расчет градиента совпал вручную и через ф-ю

# %%
# Посчитайте частные производные функций:2)  𝑓(𝑥,𝑦)=𝑥2𝑦−𝑠𝑖𝑛(𝑥𝑦)+𝑐𝑜𝑠(𝑥2)+6𝑦
def f2(v,c0,c1,c2,c3):
    return (c0 * v[0]**2*v[1]) + c1 * sin(v[0]*v[1]) + c2 * cos(v[1]**2) + c3*v[1]
c0,c1,c2,c3 = (1,-1,1,6)

from math import sin, cos
from sympy import *
x, y = symbols('x y')
print(f'Частная производная по х: {diff((x*2*y**3) - sin(x*y) + cos(y**2) + 6*y, x)}') #Частная производная по х
print(f'Частная производная по y: {diff((x*2*y**3) - sin(x*y) + cos(y**2) + 6*y, y)}')#Частная производная по y
# Out:
# Частная производная по х: 2*y**3 - y*cos(x*y)
# Частная производная по y: 6*x*y**2 - x*cos(x*y) - 2*y*sin(y**2) + 6

# %% [markdown]
# Проверим расчет частных производных руками:
#
# f'x = (x*2*y**3)'x - sin(x*y)'x + cos(y**2)'x + (6*y)'x = 2*y**3 - y*cos(x*y) + 0 + 0 - совпало
#
# f'y = (x*2*y**3)'y - sin(x*y)'y + cos(y**2)'y +(6*y)'y = 6*x*y**2 - x*cos(x*y) - 2*y*sin(y**2) + 6 - совпало

# %% [markdown]
# Уровень 1:
# Градиентный спуск своими руками:

# %%
#задаем ф-ю
def f(x,c0,c1):
    return (c0*x[0]**2) + (c1*x[1]**2)

# %%
# начальн. значение
c0, c1 = (1,1)
xn = np.array([100, 200])
yn = f(xn,c0, c1)
# шаг ГС
learning_rate = 0.1

# %%
# заводим словарь, где будем хранить все найденные значения функции
Y = {yn: xn}

# %%
Y
# Out:
# {50000: array([100, 200])}

# %%
for i in range(100):
    #находим градиент: 
    c0, c1 = (1,1)
    eps = np.sqrt(np.finfo(float).eps)
    grad = approx_fprime(xn, f, [eps, eps], c0, c1)
    # по формуле градиентного спуска получаем все значения x y:
    xn = xn - learning_rate*grad
    yn = f(xn,c0, c1)
    Y[yn] = xn
Y
# Out:
# {50000: array([100, 200]),
#  32000.0: array([ 80., 160.]),
#  20480.0: array([ 64., 128.]),
#  13107.200000000003: array([ 51.2, 102.4]),
#  8388.60900000006: array([40.95999756, 81.92000732]),
#  5368.708480000049: array([32.76799316, 65.53599854]),
#  3435.9733632000166: array([26.21439819, 52.42879639]),
#  2199.0230804480057: array([20.97151794, 41.94303894]),
#  1407.3748124467213: array([16.77721558, 33.55443115]),
#  900.7199209259011: array([13.42177277, 26.84354553]),
#  576.4607657765769: array([10.73741837, 21.47483673]),
#  368.93491631141006: array([ 8.5899353 , 17.17986984]),
#  236.11834224499833: array([ 6.87194824, 13.74389572]),
#  151.11573987565976: array([ 5.49755859, 10.99511662]),
#  96.71407486259959: array([4.39804688, 8.79609337]),
#  61.89700750941055: array([3.51843748, 7.03687468]),
#  39.61408523551951: array([2.81475   , 5.62949977]),
#  25.35301433598412: array([2.25180001, 4.50359979]),
#  16.225929003231144: array([1.80144   , 3.60287981]),
# ...

# %%
print("Минимум достигается в: ", min(Y.items())[1])
print("Значение функции в минимуме: ", min(Y.items())[0])
# Out:
# Минимум достигается в:  [1.29197811e-08 3.32901401e-08]
# Значение функции в минимуме:  1.2751541739575584e-15

# %% [markdown]
# Проверка с помощью встроенной функции numpy:

# %%
def f1(x):
    return (x[0]**2) + (x[1]**2)
x0 = np.array([100, 200])

from scipy.optimize import minimize
minimize(f1, x0, method='nelder-mead', options={'xtol': 1e-8, 'disp': True})
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 85
#          Function evaluations: 164
#  final_simplex: (array([[ 3.31391559e-09, -1.82888492e-09],
#        [-3.91522747e-09, -3.79451217e-09],
#        [-4.97134432e-09,  7.91645290e-09]]), array([1.43268566e-17, 2.97273287e-17, 8.73844908e-17]))
#            fun: 1.4326856592347756e-17
#        message: 'Optimization terminated successfully.'
#           nfev: 164
#            nit: 85
#         status: 0
#        success: True
#              x: array([ 3.31391559e-09, -1.82888492e-09])
