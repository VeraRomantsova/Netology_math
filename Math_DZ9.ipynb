# %% [markdown]
# # Домашнее задание "Центральная Предельная Теорема и Закон Больших Чисел".

# %% [markdown]
# ## Задание.
# В этом задании нужно убедиться, что ЦПТ действительно работает.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts
# %matplotlib inline

# %% [markdown]
# Создайте случайную величину из любого выбранного вами распределения, для разных значений n сгенерируйте 1000 выборок размера n и постройте гистрограммы средних этих выборок.

# %%
rv = sts.norm(loc = 2, scale = 0.3)
sample = rv.rvs(size=1000)

# %%
x = np.linspace(0,2,100)
pdf = rv.pdf(x)
plt.hist(sample, density=True, bins=30, label='sample histogram')
plt.plot(x, pdf, label='theoretical pdf', alpha=0.5)
plt.legend()
plt.ylabel('fraction of samples, $f(x)$')
plt.xlabel('$x$')
plt.show()

# %%
# Параметры запуска: размеры выборок и количество повторов генерации
sample_sizes = (2,10,30,100,1000)
sample_count = 1000
plt.figure(figsize=(17,8*len(sample_sizes))) # задаю размер ячейки 
for number, sample_size in enumerate(sample_sizes):
    sample_mean = [] # Массивы для сохранения средних по выборкам
    for generation_number in range(samples_count):
        sample = rv.rvs(size=sample_size) # На каждом цикле генерируем выборки разных размеров
        sample_mean.append(sample.mean()) # Считаем среднее по каждой выборке и добавляем в массив средних
    plt.subplot(len(sample_sizes),1,number+1) #Выводим все графики по одному в строке
    label = 'sample of ' + str(sample_size) + ' histogram'
    plt.title(label) 
    plt.hist(sample_mean, density=True,label = label)
    plt.xlim(1.2,2.8) #задаю одни и те же границы графика, чтобы было видно изменение при росте sample_size
    plt.legend()
    plt.ylabel('samples means')
    plt.xlabel('$x$')

# %% [markdown]
# Из графиков видно что с ростом n колокол сужается и вытягивается => цпт действительно работает и с ростом n средние выборок приближаются к mu исходной выборки (=2.0).
